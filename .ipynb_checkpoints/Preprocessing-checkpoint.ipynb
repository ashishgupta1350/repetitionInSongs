# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("data")

# %%
df.describe()
# Out:
#           movieName songName    songSinger songMusic songLyricist  \
# count          3027     3027          3019      3003         2906
# unique          800     2810          1688       619          772
# top     Bilal Saeed    Naina  Arijit Singh    Pritam       Kumaar
# freq             15        7           120       200          217
#
#                                                songLyrics
# count                                                3027
# unique                                               2928
# top     Chhupa bhi na sakenge\nBata bhi na sakenge\nHu...
# freq                                                    3

# %%
df.head()
# Out:
#       movieName           songName  \
# 0          Bala       Don’t Be Shy
# 1  Laal Kaptaan  Lahu Ka Rang Kara
# 2  Laal Kaptaan   Red Red Najariya
# 3  Laal Kaptaan          Kaal Kaal
# 4  Laal Kaptaan            Taandav
#
#                                     songSinger        songMusic  \
# 0  Badshah, Shalmali Kholgade, Gurdeep Mehendi     Sachin-Jigar
# 1                              Samira Koppikar  Samira Koppikar
# 2                               Shreya Ghoshal  Samira Koppikar
# 3                Brijesh Shandilya, Dino James  Samira Koppikar
# 4              Kailash Kher, Brijesh Shandilya  Samira Koppikar
#
#         songLyricist                                         songLyrics
# 0  Mellow D, Badshah  Sun, main hoon thoda sanki\nKarun mann ki\nBab...
# 1              Sahib  Morey.. lahu ka rang kara\nMorey lahu ka rang ...
# 2       Saurabh Jain  Badnaam shehar, badnaam gully\nIsme har raat h...
# 3       Saurabh Jain  Kaal kaal, kaal kaal, jo sapaat chal raha\nWo ...
# 4      Puneet Sharma  Shor hai andher mein\nJo dher murda pedon ka\n...

# %%
[x.lower() for x in list(df.songLyrics)[0].split("\n")]
# Out:
# ['sun, main hoon thoda sanki',
#  'karun mann ki',
#  'baby gaana lagade thoda funky',
#  'nahi mann ki',
#  'nahi dhan ki',
#  'ye baat hai tere tann ki',
#  '',
#  'paagal ho jaaun jab tu ho rubaru',
#  'na lamba ocha gora chitta',
#  'phir bhi dil mein tu',
#  'ishq ne tere kiya hai bekaboo',
#  'jaisa hai waisa hi pasand mujhko tu jaanu',
#  '',
#  'i just wanna feel your body',
#  '(saanu kare ishaare)',
#  'touch my body',
#  "don't be shy my honey",
#  '(saanu kare ishaare)',
#  '',
#  'i wanna feel your body',
#  '(saanu kare ishaare)',
#  'touch my body',
#  "don't be shy my honey",
#  '(saanu kare ishaare)',
#  'touch my body',
#  'fly my honey',
#  "don't be shy my honey",
#  'befikar fly my honey',
#  "don't be shy my honey",
#  '',
#  'sun, main hoon thoda sanki',
#  'karun mann ki',
#  'baby gaana lagade thoda funky',
#  'nahi mann ki',
#  'nahi dhan ki',
#  'ye baat hai tere tann ki...',
#  '',
#  'kuch bhi bole bina',
#  'aankhon se tu baat kare',
#  'ye shaitani jaan bujhke mere saath kare',
#  'tujhko dekhe bina dil mera ab kahin lage nahi',
#  'tere husn pe aankhein sek sek kar thake nahi',
#  'upar se raat hoti ja rahi hai naughty naughty naughty...',
#  "don't be shy my honey...",
#  '',
#  'i wanna feel your body',
#  '(saanu kare ishaare)',
#  'touch my body',
#  "don't be shy my honey",
#  '(saanu kare ishaare)',
#  'touch my body',
#  '',
#  'i wanna feel your body',
#  '(saanu kare ishaare)',
#  'touch my body',
#  "don't be shy my honey",
#  '(saanu kare ishaare)',
#  'touch my body',
#  '',
#  'fly my honey',
#  "don't be shy my honey",
#  'befikar fly my honey',
#  "don't be shy my honey"]

# %%
list(df.songLyrics)[1].split("\n")
# Out:
# ['Morey.. lahu ka rang kara',
#  'Morey lahu ka rang kara',
#  'Morey.. lahu ka rang kara',
#  'Morey lahu ka rang kara',
#  '',
#  'Kaare badarwa manwa mein ghoome',
#  'Kaare bhujanga sapno mein jhoome',
#  'Ghole.. zehar ki ye dhaara',
#  'Morey lahu ka rang kara',
#  'Morey.. lahu ka rang kara',
#  'Lahu ka rang kaara...',
#  '',
#  'Katit kaadank kapat kalank',
#  'Maathe mandha koi shraap hai jeevan',
#  'Raja ho ya rank',
#  'Kabila ya jhund',
#  'Har praan ka hi lakshya hai maran',
#  '',
#  'Jeetna hai jo ye rann',
#  'Kar bairi ka daman',
#  'Warna mile na chhutkaara',
#  '',
#  'Morey.. lahu ka rang kara',
#  'Morey lahu ka rang kara',
#  'Morey.. lahu ka rang kara',
#  'Morey lahu ka rang kaara...',
#  'Lahu ka... kaara...',
#  'Aa...']

# %%
'AbC fdalsfJSD'.lower()
# Out:
# 'abc fdalsfjsd'

# %%
import re

line = 'upar se raat hoti ja rahi hai\'s naughty naughty naughty...'
line = "(saanu kare ishaare)"
# remove the "" and single alphabets in these
re.split(r'[;,\s...\n()\']\s*',line)
# Out:
# ['', 'saanu', 'kare', 'ishaare', '']

# %%
import re

dataset = ''
countOfWords = 0
uniqueWords = {}
for song in list(df.songLyrics):
    listOfWords = re.split(r'[;,\s...\n()\'!?.]\s*',song) # gets me a list of words
    for word in listOfWords:
#         if word ==  '' || word=='(' || word==')' || word =='\'':
#             pass
#         else:
        word = word.lower()
        if word == 'x2':
            continue
        if word == 'x4':
            continue
        dataset+=' '+word
        countOfWords+=1
        uniqueWords[word] = 1

# %%
dataset
# Out:
# ' sun main hoon thoda sanki karun mann ki baby gaana lagade thoda funky nahi mann ki nahi dhan ki ye baat hai tere tann ki paagal ho jaaun jab tu ho rubaru na lamba ocha gora chitta phir bhi dil mein tu ishq ne tere kiya hai bekaboo jaisa hai waisa hi pasand mujhko tu jaanu i just wanna feel your body  saanu kare ishaare touch my body don t be shy my honey  saanu kare ishaare i wanna feel your body  saanu kare ishaare touch my body don t be shy my honey  saanu kare ishaare touch my body fly my honey don t be shy my honey befikar fly my honey don t be shy my honey sun main hoon thoda sanki karun mann ki baby gaana lagade thoda funky nahi mann ki nahi dhan ki ye baat hai tere tann ki   kuch bhi bole bina aankhon se tu baat kare ye shaitani jaan bujhke mere saath kare tujhko dekhe bina dil mera ab kahin lage nahi tere husn pe aankhein sek sek kar thake nahi upar se raat hoti ja rahi hai naughty naughty naughty   don t be shy my honey   i wanna feel your body  saanu kare ishaare touch my body don t be shy my honey  saanu kare ishaare touch my body i wanna feel your body  saanu kare ishaare touch my body don t be shy my honey  saanu kare ishaare touch my body fly my honey don t be shy my honey befikar fly my honey don t be shy my honey morey  lahu ka rang kara morey lahu ka rang kara morey  lahu ka rang kara morey lahu ka rang kara kaare badarwa manwa mein ghoome kaare bhujanga sapno mein jhoome ghole  zehar ki ye dhaara morey lahu ka rang kara morey  lahu ka rang kara lahu ka rang kaara   katit kaadank kapat kalank maathe mandha koi shraap hai jeevan raja ho ya rank kabila ya jhund har praan ka hi lakshya hai maran jeetna hai jo ye rann kar bairi ka daman warna mile na chhutkaara morey  lahu ka rang kara morey lahu ka rang kara morey  lahu ka rang kara morey lahu ka rang kaara   lahu ka   kaara   aa    badnaam shehar badnaam gully isme har raat hai dhoop khili isme jo dhali main khoob chali red red najariya   arey red red najariya bada jaalim kaptaan re red red najariya bada jalim kaptaan re ghaav deve karajwa mein par deve na dhyaan re red red najariya   haan  bahut aate hain iss jungle mein aisa koi aave mann ki sigdi mein maddham si  haaye aag jalaave  do pal ko jo nain milave toh haaye sab kurbaan re sab kurbaan re  aa   red red najariya  aa  red red najariya bada jaalim kaptaan re red red najariya bada jaalim kaptaan re ghaav deve karajwa mein par deve na dhyaan re ghaav deve karajwa mein par deve na dhyaan re red red najariya haaye    kaal kaal kaal kaal jo sapaat chal raha wo kaal kaal kaal kaal hai kaal kaal kaal kaal jo sapaat chal raha wo kaal kaal kaal kaal hai gol gol duniya mein gol gol sadiyon se chal rahi woh ek hi mashaal hai kaal kaal kaal kaal jo sapaat chal raha wo kaal kaal kaal kaal hai kaal kaal kaal kaal jo sapaat chal raha wo kaal kaal kaal kaal hai aadmi toh bandar sa banke par sikandar sa aadmi toh bandar sa banke par sikandar sa neetiyon ka dambh roz bharta hai pal mein ek peedhi hai umra ek seedhi hai chadhta roz roz hi phisalta hai par aham mein jeeta hai kis vaham mein jeeta hai rakt mein kyun uske ye ubaal hai kaal kaal kaal kaal jo sapaat chal raha wo kaal kaal kaal kaal hai kaal kaal kaal kaal jo sapaat chal raha wo kaal kaal kaal kaal hai khatm na hoti hai teri ye laalsa jaane ka samay tu bhale hai taalta karega kya murjhati iss khaal ka bas mein na hai sab khel hai kaal ka saaya hai kaal ka saare bramhaand mein teer vinash ka uske kamaan mein deta woh bhar hai saansein wo praan mein pratyaksh khada hai uske pramaan mein wo ajar hai wo amar hai wo anaadi ant hai granth saare dharm saare uska hi shadyantra hai gada hai chaatiyon mein   samay ka shool hai usko bhoolna bhool hai bhool hai  sab isi ke maare hai sab isi se haare hai isko jeet le wo mahakaal hai kaal kaal kaal kaal jo sapaat chal raha wo kaal kaal kaal kaal hai kaal kaal kaal kaal jo sapaat chal raha wo kaal kaal kaal kaal hai shor hai andher mein jo dher murda pedon ka sulag gaya jhulas gaya lo jwala jwala aag hai kaath hi ke dher mein ...

# %%
countOfWords
# Out:
# 550499

# %%
len(uniqueWords.keys())
# Out:
# 33164

# %%
d[1] = 3
d[2] = 4
d
# Out:
# {1: 3, 2: 4}

# %%
import os
import nltk
import gensim
from gensim import corpora, models, similarities

# %%
listDataset = list(dataset)

# %%
model = gensim.models.Word2Vec(dataset, min_count = 1, size = 32)

# %%
from gensim.test.utils import common_texts

# %%
common_texts
# Out:
# [['human', 'interface', 'computer'],
#  ['survey', 'user', 'computer', 'system', 'response', 'time'],
#  ['eps', 'user', 'interface', 'system'],
#  ['system', 'human', 'system', 'eps'],
#  ['user', 'response', 'time'],
#  ['trees'],
#  ['graph', 'trees'],
#  ['graph', 'minors', 'trees'],
#  ['graph', 'minors', 'survey']]

# %%
import re

dataset_gensim = []
countOfWords = 0
uniqueWords = {}
for song in list(df.songLyrics):
    listOfWords = re.split(r'[;,\s...\n()\'!?.]\s*',song) # gets me a list of words
    wordList = []
    for word in listOfWords:
#         if word ==  '' || word=='(' || word==')' || word =='\'':
#             pass
#         else:
        word = word.lower()
        if word == 'x2':
            continue
        if word == 'x4':
            continue
        wordList.append(word)
        countOfWords+=1
        uniqueWords[word] = 1
    dataset_gensim.append(wordList)

# %%
model = gensim.models.Word2Vec(dataset_gensim, min_count = 1, size = 64)

# %%
model.most_similar("ladki")
# Out:
# C:\Users\ashis\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('chhooti', 0.9722440242767334),
#  ('uljhi', 0.9696261882781982),
#  ('teekhi', 0.9643558263778687),
#  ('meethi', 0.9634658098220825),
#  ('nam', 0.9633132219314575),
#  ('rangat', 0.9599862098693848),
#  ('nadi', 0.9589784145355225),
#  ('lipti', 0.9573204517364502),
#  ('roothi', 0.9553119540214539),
#  ('ummeed', 0.9537785053253174)]

# %%
model2 = gensim.models.Word2Vec(dataset_gensim, size=100, window=5, min_count=1)

# %%
model2.most_similar("ladki")
# Out:
# C:\Users\ashis\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('nadi', 0.9722105860710144),
#  ('meethi', 0.9683970212936401),
#  ('koshish', 0.9638593792915344),
#  ('chhooti', 0.9633733034133911),
#  ('bhule', 0.9625373482704163),
#  ('nam', 0.9618449211120605),
#  ('pagli', 0.9606292247772217),
#  ('honeymoon', 0.9585255980491638),
#  ('roothi', 0.9561929106712341),
#  ('bolti', 0.9560897350311279)]

# %%
model3 = gensim.models.FastText(size=4, window=10, min_count=1, sentences=dataset_gensim, iter=10)

# %%
model3.most_similar("ladki")
# Out:
# C:\Users\ashis\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('gungunaati', 0.9997197985649109),
#  ('roti-shoti', 0.9992340803146362),
#  ('meethi-meethi', 0.9988754391670227),
#  ('gungunati', 0.9982720613479614),
#  ('dhoom', 0.9979858994483948),
#  ('karte', 0.9979594945907593),
#  ('gungunaate', 0.9969856142997742),
#  ('dosi', 0.9969304800033569),
#  ('lete', 0.996864914894104),
#  ('ghoomenge', 0.9967324733734131)]

# %%
model4 = gensim.models.wrappers.Wordrank.train(dataset_gensim, corpus_file='text8', out_name='wr_model')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-76-14215a788d84> in <module>
# ----> 1 model4 = gensim.models.wrappers.Wordrank.train(dataset_gensim, corpus_file='text8', out_name='wr_model')
#
# ~\Anaconda3\lib\site-packages\gensim\models\wrappers\wordrank.py in train(cls, wr_path, corpus_file, out_name, size, window, symmetric, min_count, max_vocab_size, sgd_num, lrate, period, iter, epsilon, dump_period, reg, alpha, beta, loss, memory, np, cleanup_files, sorted_vocab, ensemble)
#     141
#     142         # prepare training data (cooccurrence matrix and vocab)
# --> 143         model_dir = os.path.join(wr_path, out_name)
#     144         meta_dir = os.path.join(model_dir, 'meta')
#     145         os.makedirs(meta_dir)
#
# ~\Anaconda3\lib\ntpath.py in join(path, *paths)
#      74 # Join two (or more) paths.
#      75 def join(path, *paths):
# ---> 76     path = os.fspath(path)
#      77     if isinstance(path, bytes):
#      78         sep = b'\\'
#
# TypeError: expected str, bytes or os.PathLike object, not list
