# %%
# !pip install azlyrics
# Out:
# Collecting azlyrics
#   Downloading https://files.pythonhosted.org/packages/b1/b2/7f286aa9b24503fd56337f4c499cbaaca062dac22746e6c18dc16155793e/azlyrics-1.3.2-py2.py3-none-any.whl
# Requirement already satisfied: requests in c:\users\ashis\anaconda3\lib\site-packages (from azlyrics) (2.22.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\ashis\anaconda3\lib\site-packages (from azlyrics) (4.7.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\ashis\anaconda3\lib\site-packages (from requests->azlyrics) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ashis\anaconda3\lib\site-packages (from requests->azlyrics) (2019.6.16)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\ashis\anaconda3\lib\site-packages (from requests->azlyrics) (1.24.2)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\ashis\anaconda3\lib\site-packages (from requests->azlyrics) (2.8)
# Requirement already satisfied: soupsieve>=1.2 in c:\users\ashis\anaconda3\lib\site-packages (from beautifulsoup4->azlyrics) (1.8)
# Installing collected packages: azlyrics
# Successfully installed azlyrics-1.3.2

# %%
from azlyrics.azlyrics import artists,songs, lyrics

# %%
artists("a")
# songs("Arijit Singh")
# Out:
# '["A1", "A", "Aalegra, Snoh", "Aaliyah", "Aalto, Saara", "Aaradhna", "Aaron Carpenter", "Aaron Carter", "Aaron Cole", "Aaron Doh", "Aaron Fresh", "Aaron Goodvin", "Aaron Lewis", "Aaron Lines", "Aaron May", "Aaron Neville", "Aaron Shust", "Aaron Smith", "Aaron Tippin", "Aaron Watson", "Aaron West And The Roaring Twenties", "AB6IX", "Abandon All Ships", "Abandoned Pools", "ABBA", "Abbott, Gregory", "Abby Anderson", "ABC", "Abdul, Paula", "Abel, Zak", "Abhi The Nomad", "Abigail Breslin", "ABK (Anybody Killa)", "Aborted", "Abou Debeing", "Above & Beyond", "Above The Hood", "Abra", "ABRA", "Abra Cadabra", "Abraham Mateo", "Abrams, Casey", "Abs", "Absofacto", "Ab-Soul", "Abstract", "Abstract, Kevin", "Abu", "Acacia Strain, The", "Academic, The", "Academy Is..., The", "Accept", "Acceptance", "AC/DC", "Ace", "ACE Family, The", "Ace Frehley", "Ace Hood", "Ace Of Base", "Aces, The", "A.CHAL", "Achille Lauro", "Action Action", "Action Bronson", "Active Child", "Actor | Observer", "ADA Band", "Adam Ant", "Adam Calhoun", "Adam Craig", "Adam Doleac", "Adam Friedman", "Adam Gontier", "Adam Gregory", "Adam Jensen", "Adam Lambert", "Adamlar", "Adam Levine", "Adam Saleh", "Adam Sandler", "Adams, Bryan", "Adams, Chloe", "Adams, Joel", "Adams, Oleta", "Adams, Peter Bradley", "Adams, Ryan", "Adams, Sammy", "Adams, Simon", "Adams, Yolanda", "Adara, Ivy", "Addison Road", "Adecer, Migo", "Adekunle Gold", "Adele", "Adelen", "Adelitas Way", "Adel Tawil", "Adema", "Adept", "Adera", "Adina Howard", "Adi Nowak", "Adkins, Trace", "Adnan Sami", "Adolescents", "Adore Delano", "Adrian Marcel", "Adriano Celentano", "Adriel Favela", "Adrienne Bailon", "Adventure Club", "Ady Suleiman", "Aegis", "Aer", "Aerosmith", "Aesop Rock", "Afgan", "Afghan Whigs, The", "AFI", "Afro B", "Afrojack", "Afroman", "After 7", "After Forever", "Afterimage, The", "Afterlife", "Afters, The", "After The Burial", "Against Me!", "Against The Current", "Agent Orange", "Age Of Information, The", "Aggro Santos", "Agnes", "Agnes Monica", "Agnes Obel", "Agnetha Faltskog", "Agnew, Todd", "Agonist, The", "Agony Scene, The", "Agsunta", "Aguilar, Freddie", "Aguilar, Pepe", "Aguilera, Christina", "Agust D", "A-ha", "Aha Gazelle", "Ahn, Priscilla", "Ahsen Almaz", "Aiden", "Aiden Grimshaw", "Aidonia", "AIGEL (\\u0410\\u0418\\u0413\\u0415\\u041b)", "Aiken, Clay", "Aiko, Jhene", "Ailee", "Aiman Tino", "Aimee Mann", "Aimyon", "Air", "Airborne Toxic Event, The", "Airbourne", "Air Supply", "Air Traffic Controller", "Aisha Badru", "Aitana", "Aitch", "Aiza Seguerra", "Aja", "AJ McLean", "AJ Michalka", "AJ Mitchell", "AJR", "AJ Rafael", "AJ Tracey", "AJ x Deno", "AKA", "Akcent", "Akdong Musician (AKMU)", "Akia", "Akinyele", "Akon", "Akridge, Christian", "Alabama", "Alabama Shakes", "Alacranes Musical", "Alade, Yemi", "Alaina, Lauren", "Alamid", "Alana Lee", "Alanis Morissette", "Alan Jackson", "Alannah Myles", "Alan Parsons Project, The", "Alan Walker", "Alaska Thunderfuck", "Alayna", "ALAZKA", "Albarn, Damon", "Albert Hammond", "Albert Hammond, Jr.", "Alberts, Ziggy", "Alboran, Pablo", "Alcasid, Ogie", "Alcatrazz", "Alchemist, The", "Aldair Playboy", "Aldean, Jason", "Alden Richards", "Aldo Nova", "Aldous Harding", "Alec Benjamin", "Aleesia", "Alejandra Guzman", "Alejandro Fernandez", "Alejandro Sanz", "Alem\\u00e1n", "Alesana", "Alesha Dixon", "Alessia Cara", "Alesso", "Alestorm", "Alexa Goddard", "Alexa Ilacad", "Alex Aiono", "Alexander, Dean", "Alexander Diaz", "Alexander Jean", "Alexander Ludwig", "Alexander Oscar", "Alexander Rybak", "Alexandra Burke", "Alexandra Stan", "Alexa Vega", "Alex Band", "Alex Cameron", "Alex Campos", "Alex Clare", "Alex Da Kid", "Alex Day", "Alex G", "Alex Gaudino", "Alex Gonzaga", "Alex Goot", "Alex Hepburn", "Alexiane", "Alexi Murdoch", "Alexis Jordan", "Alexisonfire", "Alexis Y Fido", "Alex Lahey", "Alex Lora", "Alex Mattson", "Alex Mica", "Alex Parks", "Alex Rose", "Alex Sensation", "Alex & Sierra", "Alex Turner", "Alex Vargas", "Alexx Calise", "Alexz Johnson", "Aleyna" ...

# %%
print( songs("Shreya Ghoshal"))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-cbd75cf2af79> in <module>
# ----> 1 print( songs("Shreya Ghoshal"))
#
# ~\Anaconda3\lib\site-packages\azlyrics\azlyrics.py in songs(artist)
#      40
#      41     all_albums = soup.find('div', id='listAlbum')
# ---> 42     first_album = all_albums.find('div', class_='album')
#      43     album_name = first_album.b.text
#      44     songs = []
#
# AttributeError: 'NoneType' object has no attribute 'find'

# %%
print(songs("Bollywood"))
# Out:
# {"artist": "bollywood", "albums": {"\"Shubh Mangal Saavdhan\"": ["Rocket Saiyyan", "Kanha", "Laddoo", "Kankad"], "\"Lucknow Central\"": ["Kaavaan Kaavaan", "Meer-e-Kaarwan", "Teen Kabootar", "Rangdaari", "Kaavaan Kaavaan (Remix)", "Baaki Rab Pe Chhod De"], "\"Simran\"": ["Lagdi Hai Thaai", "Pinjra Tod Ke", "Meet", "Majaa Ni Life / Single Rehne De", "Simran", "Baras Ja"], "\"Judwaa 2\"": ["Chalti Hai Kya 9 Se 12", "Suno Ganpati Bappa Morya", "Oonchi Hai Building 2.0", "Aa To Sahi"], "\"Chef\"": ["Shugal Laga Le", "Tere Mere", "Banjara", "Tan Tan", "Khoya Khoya", "Darmiyaan"], "\"Secret Superstar\"": ["Main Kaun Hoon", "Meri Pyaari Ammi", "Sapne Re", "I'll Miss You", "Nachdi Phira", "Sexy Baliye", "Gudgudi", "O Re Manwa"], "\"Qarib Qarib Singlle\"": ["Khatam Kahani", "Tu Chale Toh", "Jaane De", "Tanha Begum"], "\"Shaadi Mein Zaroor Aana\"": ["Jogi", "Main Hoon Saath Tere", "Pallo Latke", "Tu Banja Gali Benaras Ki", "Mera Intkam Dekhegi"], "\"Firangi\"": ["Oye Firangi", "Sajna Sohne Jiha", "Sahiba Russ Gayiya", "Tu Jit Jawna", "Gulbadan"], "\"Fukrey Returns\"": ["Mehbooba", "Peh Gaya Khalara", "Tu Mera Bhai Nahi Hai", "Ishq De Fanniyar", "Ishq De Fanniyar  (Female Version)", "Fukrey Returns", "Raina", "Bura Na Mano Bholi Hai"], "\"Tiger Zinda Hai\"": ["Swag Se Swagat", "Dil Diyan Gallan", "Zinda Hai", "Daata Tu", "Tera Noor", "Dil Diyan Gallan (Unplugged)"], "\"1921\"": ["Sunn Le Zara", "Kuch Iss Tarah", "Yaara", "Tere Bina", "Aanewale Kal"], "\"Padmaavat\"": ["Ghoomar", "Ek Dil Ek Jaan", "Khalibali", "Nainowale Ne", "Holi (Manganiyars & Langa's Folk Song)", "Binte Dil"], "\"Padman\"": ["Aaj Se Teri", "The Pad Man Song", "Hu Ba Hu", "Saale Sapne", "Sayaani"], "\"Aiyaary\"": ["Lae Dooba", "Yaad Hai", "Shuru Kar"], "\"Sonu Ke Titu Ki Sweety\"": ["Dil Chori", "Subah Subah", "Chhote Chhote Peg", "Bom Diggy", "Kaun Nachdi", "Lakk Mera Hit", "Tera Yaar Hoon Main", "Sweety Slowly Slowly"], "\"Pari\"": ["Meri Khamoshi Hai", "So Ja So Ja"], "\"Veerey Ki Wedding\"": ["Mind Blowing", "Hatt Ja Tau", "Veerey Ki Wedding", "Talli Tonight", "Na Kasoor"], "\"3 Storeys\"": ["Bas Tu Hai", "Raasleela", "Azaadiyaan", "Zaroori Bewakoofi"], "\"Baa Baaa Black Sheep\"": ["Baa Baaa Black Sheep", "Heer", "Angelina", "Ram Leela", "Gallan Goriyan / Aaja Soniye"], "\"Dil Juunglee\"": ["Nachle Na", "Gazab Ka Hai Din", "Beat Juunglee", "Bandeya", "Dil Jaane Na"], "\"Hate Story IV\"": ["Aashiq Banaya Aapne", "Boond Boond", "Tum Mere Ho", "Badnaamiyan", "Naam Hai Mera", "Mohabbat Nasha Hai (Duet)"], "\"Laung Laachi\"": ["Laung Laachi (Title Song)", "Akhiyaan Naar Diyaan", "Chidi Blauri", "Rooh De Rukh", "Logo Muchh De", "Sheesha", "Radio"], "\"RAID\"": ["Sanu Ek Pal Chain", "Nit Khair Manga", "Black Jama Hai", "Jhuk Na Paunga"], "\"Raja Abroadiya\"": ["Banke Saanse"], "\"Daas Dev\"": ["Sehmi Hai Dhadkan", "Rangdaari", "Challa Chaap Chunariya", "Raat Youn Dil Main Teri", "Azaad Kar", "Tain To Uttey", "Marne Ka Shauk"], "\"Hichki\"": ["Oye Hichki", "Madamji Go Easy", "Khol De Par", "Teri Dastaan", "Phir Kya Hai Gham"], "\"Sajjan Singh Rangroot\"": ["Roti", "Sajjana", "Pyaas", "Peepa", "Mera Ki Mareya", "Firdosya"], "\"Shaadi Teri Bajayenge Hum Band\"": ["Shaadi Teri Bajayenge Hum Band (Title Track)", "Yaar Di Barat"], "\"Baaghi 2\"": ["Mundiyan", "O Saathi", "Lo Safar", "Ek Do Teen", "Soniye Dil Nayi", "Get Ready To Fight Again"], "\"Blackmail\"": ["Happy Happy", "Patola", "Bewafa Beauty", "Badla", "Nindaraan Diyaan", "Sataasat"], "\"Mercury\"": ["The Mercury Song"], "\"October\"": ["Theher Ja", "Tab Bhi Tu", "Manwaa", "Chal"], "\"Khido Khundi\"": ["Zor Se Zor Laga", "Watna Ve", "Dillagi", "Apnya Di Thaa"], "\"Nanu Ki Jaanu\"": ["Tere Thumke Sapna Choudhary", "Bhoot Aaya", "Tujhe Dekhti Hai Nazar", "Kali Choti", "Jai Mata Di"], "\"102 Not Out\"": ["Bachche Ki Jaan", "Badumba", "Kulfi", "Kuch Anokhe Rules", "Phir Laut Aayi Zindagi", "Waqt Ne Kiya Kya Haseen Sitam"], "\"Raazi\"": ["Ae Watan", "Dilbaro", "Raazi", "Ae Watan (Female Version)"], "\"Parmanu: The Story Of  ...

# %%
print(songs("Atif Aslam"))
# Out:
# {"artist": "atifaslam", "albums": {"\"Jal Pari\"": ["Aadat", "Ehsaas", "Zindagi", "Yakeen", "Aakhon Se", "Aadat (Deep Blue Version)", "Mahi Ve", "Jal Pari", "Bheegi Yaadein", "Tehzeeb", "Gal Sun Ja"], "\"Doorie\"": ["Doorie", "Ehsaas", "Hum Kis Galli Jaa Rahe Hai", "Kuch Is Tarah", "O Re Piya", "Mahi Ve", "Mahiya Ve Soniya", "Maula", "Yakeen", "Doorie (House Mix)", "Kuch Is Tarah (Euro Mix)", "Mahiya Ve Soniya (Soul Mix)", "O Re Piya (Trance Mix)", "Yakeen (Club Mix)", "Doorie (Energy Mix)", "Mahi Ve (Eternal Mix)", "Hum Kis Gali Ja Rahe Hain (Dance Mix)", "Ehsaas (Freaky Mix)"], "\"Meri Kahani\"": ["12 Bajay", "Aa Bhi Ja Mere Mehermaan", "Aa Bhi Ja Sanam", "Anjaana", "Auliya", "Baarish", "Baarishein", "Bairiya", "Bakhuda Tumhi Ho", "Be Intehaan", "Chalte Chalte", "Channa", "Darasal", "Dekhte Dekhte", "Dil Diyan Gallan", "Dil Kare", "Dil Mere Na Sune", "Dil Yeh Dancer Hogaya", "Hona Tha Pyar", "Hoor", "In Dinon", "Jaane De", "Jab Koi Baat", "Jeena Jeena", "Jeene Laga Hoon", "Kaho (Aaj Bol Do)", "Kasam", "Kaun Hoon Main", "Khair Mangda", "Main Agar", "Main Rang Sharbaton Ka", "Mar Jaayen", "Mithe Alo", "Musafir", "Nahin Woh Saamne", "Noor E Azal", "O Mere Khuda", "O Meri Laila", "O Saathi", "Paniyon Sa", "Pardadari", "Pehli Dafa", "Pehli Nazar Mein", "Sehmi Hai Dhadkan", "Selfish", "Tajdar-E-Haram", "Tera Hone Laga Hoon", "Tera Hua", "Tera Naam Doon", "Tere Bin", "Tere Liye", "Tere Sang Yaara", "Thaam Lo", "Toota Jo Kabhi Taara", "Tu Chahiye", "Tu Jaane Na", "Tum", "Woh Lamhe Woh Baatein", "Wohi Khuda Hai", "Younhi"]}}

# %%
print(lyrics("Atif Aslam", "Zindagi"))
# Out:
# ['\n\r\nrangon mein\nkhwaabon mein\nhum sabhi\nnainan mein\naakhiyan mein\ntum jo kabhi\n\napne haath zara tu utha le\nmaang le rab se duaa\nke wo baatde saari khushiyaan\nbholaade wo saare gham\n\nrangon mein\nkhwaabon mein\nhum sabhi\nnainan mein\naakhiyan mein\ntum jo kabhi\n\nzindagi zara tu jhoom le\napne gird zara tu dekhle\nbaatde saari khushiyan\nbholaade wo saare gham\n\nke rahe hum rangon mein\nke rahe hum khuwaabo mein\nke rahe hum rangon mein\nke rahe hum khuwaabo mein\n\nke rahe hum rangon mein\nke rahe hum khuwaabo mein\nke rahe hum rangon mein\nke rahe hum khuwaabo mein\n']

# %%
print(songs("arijitsingh"))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-d0794c1df8e6> in <module>
# ----> 1 print(songs("arijitsingh"))
#
# ~\Anaconda3\lib\site-packages\azlyrics\azlyrics.py in songs(artist)
#      40
#      41     all_albums = soup.find('div', id='listAlbum')
# ---> 42     first_album = all_albums.find('div', class_='album')
#      43     album_name = first_album.b.text
#      44     songs = []
#
# AttributeError: 'NoneType' object has no attribute 'find'

# %%
# !pip install azapi
# Out:
# Collecting azapi
#   Downloading https://files.pythonhosted.org/packages/5b/16/6f064d330229673f8ac3dce5af80a1497cf1426d89fe32f248e6a72da3c6/azapi-2.1.0-py3-none-any.whl
# Requirement already satisfied: requests in c:\users\ashis\anaconda3\lib\site-packages (from azapi) (2.22.0)
# Collecting bs4 (from azapi)
#   Downloading https://files.pythonhosted.org/packages/10/ed/7e8b97591f6f456174139ec089c769f89a94a1a4025fe967691de971f314/bs4-0.0.1.tar.gz
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ashis\anaconda3\lib\site-packages (from requests->azapi) (2019.6.16)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\ashis\anaconda3\lib\site-packages (from requests->azapi) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\ashis\anaconda3\lib\site-packages (from requests->azapi) (2.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\ashis\anaconda3\lib\site-packages (from requests->azapi) (1.24.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\ashis\anaconda3\lib\site-packages (from bs4->azapi) (4.7.1)
# Requirement already satisfied: soupsieve>=1.2 in c:\users\ashis\anaconda3\lib\site-packages (from beautifulsoup4->bs4->azapi) (1.8)
# Building wheels for collected packages: bs4
#   Building wheel for bs4 (setup.py): started
#   Building wheel for bs4 (setup.py): finished with status 'done'
#   Stored in directory: C:\Users\ashis\AppData\Local\pip\Cache\wheels\a0\b0\b2\4f80b9456b87abedbc0bf2d52235414c3467d8889be38dd472
# Successfully built bs4
# Installing collected packages: bs4, azapi
# Successfully installed azapi-2.1.0 bs4-0.0.1

# %%
from azapi import AZlyrics
import pprint

api = AZlyrics()

songs = api.getSongs('Sonu Nigam')

# pprint.pprint(songs, indent=5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-209be11b4d04> in <module>
#       4 api = AZlyrics()
#       5
# ----> 6 songs = api.getSongs('Sonu Nigam')
#       7
#       8 # pprint.pprint(songs, indent=5)
#
# ~\Anaconda3\lib\site-packages\azapi\azapi.py in getSongs(self, artist, search)
#     151         albums_page = self.get(link)
#     152
# --> 153         return ParseSongs(albums_page)
#     154
#     155     def search(self, query, category='songs', limit=1):
#
# ~\Anaconda3\lib\site-packages\azapi\tools.py in ParseSongs(page)
#      35     Parent = htmlFind(page)('div', {'id':'listAlbum'})
#      36
# ---> 37     Raw_Data = Parent.findChildren()
#      38
#      39     songs = {}
#
# AttributeError: 'NoneType' object has no attribute 'findChildren'

# %%
print(songs)
# Out:
# {'Aadat': {'year': '2004', 'album': 'Jal Pari', 'type': 'album', 'url': 'http://www.azlyrics.com/lyrics/atifaslam/aadat.html'}, 'Ehsaas': {'year': '2006', 'album': 'Doorie', 'type': 'album', 'url': 'http://www.azlyrics.com/lyrics/atifaslam/ehsaas.html'}, 'Zindagi': {'year': '2004', 'album': 'Jal Pari', 'type': 'album', 'url': 'http://www.azlyrics.com/lyrics/atifaslam/zindagi.html'}, 'Yakeen': {'year': '2006', 'album': 'Doorie', 'type': 'album', 'url': 'http://www.azlyrics.com/lyrics/atifaslam/yakeen.html'}, 'Aakhon Se': {'year': '2004', 'album': 'Jal Pari', 'type': 'album', 'url': 'http://www.azlyrics.com/lyrics/atifaslam/aakhonse.html'}, 'Aadat (Deep Blue Version)': {'year': '2004', 'album': 'Jal Pari', 'type': 'album', 'url': 'http://www.azlyrics.com/lyrics/atifaslam/aadatdeepblueversion.html'}, 'Mahi Ve': {'year': '2006', 'album': 'Doorie', 'type': 'album', 'url': 'http://www.azlyrics.com/lyrics/atifaslam/mahive.html'}, 'Jal Pari': {'year': '2004', 'album': 'Jal Pari', 'type': 'album', 'url': 'http://www.azlyrics.com/lyrics/atifaslam/jalpari.html'}, 'Bheegi Yaadein': {'year': '2004', 'album': 'Jal Pari', 'type': 'album', 'url': 'http://www.azlyrics.com/lyrics/atifaslam/bheegiyadien.html'}, 'Tehzeeb': {'year': '2004', 'album': 'Jal Pari', 'type': 'album', 'url': 'http://www.azlyrics.com/lyrics/atifaslam/tehzeeb.html'}, 'Gal Sun Ja': {'year': '2004', 'album': 'Jal Pari', 'type': 'album', 'url': 'http://www.azlyrics.com/lyrics/atifaslam/galsunja.html'}, 'Doorie': {'year': '2006', 'album': 'Doorie', 'type': 'album', 'url': 'http://www.azlyrics.com/lyrics/atifaslam/doorie.html'}, 'Hum Kis Galli Jaa Rahe Hai': {'year': '2006', 'album': 'Doorie', 'type': 'album', 'url': 'http://www.azlyrics.com/lyrics/atifaslam/humkisgallijaarahehai.html'}, 'Kuch Is Tarah': {'year': '2006', 'album': 'Doorie', 'type': 'album', 'url': 'http://www.azlyrics.com/lyrics/atifaslam/kuchistarah.html'}, 'O Re Piya': {'year': '2006', 'album': 'Doorie', 'type': 'album', 'url': 'http://www.azlyrics.com/lyrics/atifaslam/orepiya.html'}, 'Mahiya Ve Soniya': {'year': '2006', 'album': 'Doorie', 'type': 'album', 'url': 'http://www.azlyrics.com/lyrics/atifaslam/mahiyavesoniya.html'}, 'Maula': {'year': '2006', 'album': 'Doorie', 'type': 'album', 'url': 'http://www.azlyrics.com/lyrics/atifaslam/maula.html'}, 'Doorie (House Mix)': {'year': '2006', 'album': 'Doorie', 'type': 'album', 'url': 'http://www.azlyrics.com/lyrics/atifaslam/dooriehousemix.html'}, 'Kuch Is Tarah (Euro Mix)': {'year': '2006', 'album': 'Doorie', 'type': 'album', 'url': 'http://www.azlyrics.com/lyrics/atifaslam/kuchistaraheuromix.html'}, 'Mahiya Ve Soniya (Soul Mix)': {'year': '2006', 'album': 'Doorie', 'type': 'album', 'url': 'http://www.azlyrics.com/lyrics/atifaslam/mahiyavesoniyasoulmix.html'}, 'O Re Piya (Trance Mix)': {'year': '2006', 'album': 'Doorie', 'type': 'album', 'url': 'http://www.azlyrics.com/lyrics/atifaslam/orepiyatrancemix.html'}, 'Yakeen (Club Mix)': {'year': '2006', 'album': 'Doorie', 'type': 'album', 'url': 'http://www.azlyrics.com/lyrics/atifaslam/yakeenclubmix.html'}, 'Doorie (Energy Mix)': {'year': '2006', 'album': 'Doorie', 'type': 'album', 'url': 'http://www.azlyrics.com/lyrics/atifaslam/doorieenergymix.html'}, 'Mahi Ve (Eternal Mix)': {'year': '2006', 'album': 'Doorie', 'type': 'album', 'url': 'http://www.azlyrics.com/lyrics/atifaslam/mahiveeternalmix.html'}, 'Hum Kis Gali Ja Rahe Hain (Dance Mix)': {'year': '2006', 'album': 'Doorie', 'type': 'album', 'url': 'http://www.azlyrics.com/lyrics/atifaslam/humkisgalijarahehaindancemix.html'}, 'Ehsaas (Freaky Mix)': {'year': '2006', 'album': 'Doorie', 'type': 'album', 'url': 'http://www.azlyrics.com/lyrics/atifaslam/ehsaasfreakymix.html'}, 'Meri Kahani': {'year': '2008', 'album': 'Meri Kahani', 'type': 'album', 'url': 'http://www.azlyrics.com/lyrics/atifaslam/merikahani.html'}, 'Kinara': {'year': '2008', 'album': 'Meri Kahani', 'type': 'album', 'url': 'http://www.azlyrics.com/lyrics/atifaslam/kinara.html'}, 'Rabba Sacheya': {'year': ...

# %%
import string
import time
import re
import urllib
def lyrics(artist,song):
    artist = artist.lower()
    song = song.lower()
    artist = re.sub('[^A-Za-z0-9]+', "", artist)
    song = re.sub('[^A-Za-z0-9]+', "", song)
    raw_html = urllib.urlopen("http://azlyrics.com/lyrics/"+str(artist)+"/"+str(song)+".html")
    html_copy = str(raw_html.read())
    split = html_copy.split('<!-- Usage of http://azlyrics.com     content by any third-party lyrics provider is prohibited by our licensing agreement. Sorry about that. -->',1)
    split_html = split[1]
    split = split_html.split('</div>',1)
    lyrics = split[0]
    lyrics = re.sub('(<.*?>)',"",lyrics)
 
    return lyrics

lyrics("arijitsingh","pachtaoge")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-2a09d3bb50b3> in <module>
#      18     return lyrics
#      19
# ---> 20 lyrics("arijitsingh","pachtaoge")
#
# <ipython-input-41-2a09d3bb50b3> in lyrics(artist, song)
#       8     artist = re.sub('[^A-Za-z0-9]+', "", artist)
#       9     song = re.sub('[^A-Za-z0-9]+', "", song)
# ---> 10     raw_html = urllib.urlopen("http://azlyrics.com/lyrics/"+str(artist)+"/"+str(song)+".html")
#      11     html_copy = str(raw_html.read())
#      12     split = html_copy.split('<!-- Usage of http://azlyrics.com     content by any third-party lyrics provider is prohibited by our licensing agreement. Sorry about that. -->',1)
#
# AttributeError: module 'urllib' has no attribute 'urlopen'
